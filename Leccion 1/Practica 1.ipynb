# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data=pd.read_csv("./Disease_symptom_and_patient_profile_dataset.csv")
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data=pd.read_csv("./Disease_symptom_and_patient_profile_dataset.csv")
#       2 data
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ¿Cúales son las variables que contiene este conjunto de datos?
#
# Las variables que contiene el conjunto de datos son los encabezados de las columnas los cuales (en español) son:
#
# Tipo de enfermedad
# Un valor booleano para saber si el padecimiento presenta: fiebre, tos, fatiga y dificultad para respirar
# Edad del paciente
# Genero del paciente
# El nivel de presión arterial ya sea bajo, normal o alto
# El nivel de colesterol
# Una variable que indica si el paciente tiene la enfermedad en cuestión
